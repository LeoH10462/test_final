# %%
import numpy as np
import pandas as pd

# %%
police_pop = pd.read_csv('static/police_poplulation.csv')
police_pop
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 police_pop = pd.read_csv('static/police_poplulation.csv')
#       2 police_pop
#
# File ~/miniforge3/envs/dsc80/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
for col in police_pop.columns[1:]:  # Assuming the first column is 'county_name' and should not be converted
    police_pop[col] = police_pop[col].str.replace(',', '').astype(int)

police_pop
# Out:
#         county_name   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0           Alameda   5363   5509   5508   5570   5593   5481   5433   5482
# 1            Alpine     20     17     20     20     19     18     21     20
# 2            Amador    147    156    160    147    147    151    162    159
# 3             Butte    792    778    799    785    776    776    739    754
# 4         Calaveras    133    131    131    142    139    138    159    172
# 5            Colusa    120    121    110    115    112    109    113    116
# 6      Contra Costa   2851   2885   2814   2824   2893   2997   2975   2946
# 7         Del Norte    122    118    113    120    111    103    113    117
# 8         El Dorado    613    624    620    623    633    622    618    614
# 9            Fresno   3416   3464   3588   3719   3804   3956   4019   3977
# 10            Glenn    110    114    111    110    100    102    111    102
# ...

# %%
# police_pop.to_csv('static/police_poplulation1.csv', index=False)

# %%
df = pd.read_csv('static/police_poplulation1.csv')
new_df = df.set_index('county_name').T
new_df = new_df.reset_index().rename(columns={'index':'year'})

new_df.head()
new_df.to_csv('static/temp_all_pop.csv', index= False)
